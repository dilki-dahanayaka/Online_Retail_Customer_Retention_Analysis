# %%
import pandas as pd
import os

# Data Understanding
raw_data_path = os.path.join("..", "data", "raw", "Online Retail.xlsx")
df = pd.read_excel(raw_data_path, engine='openpyxl')

print("--- DATA UNDERSTANDING STAGE ---")
print(f"🔹 Total number of data rows: {len(df)}")
print(f"🔹 Total number of data Columns : {len(df.columns)}")
print("\n Types of data in each column:")
print(df.dtypes)

print("\n Missing Values:")
print(df.isnull().sum())
# Out:
# --- DATA UNDERSTANDING STAGE ---
# 🔹 Total number of data rows: 541909
# 🔹 Total number of data Columns : 8
#
#  Types of data in each column:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object
#
#  Missing Values:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64
