# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..')))
from src.feature_engineering import add_features
import pandas as pd

# 1. CSV data read
df = pd.read_csv('../data/processed/cleaned_online_retail.csv')

# 2.datatime convert to invoicedate
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# 3. Feature Engineering 
df = add_features(df)

# 4. Statistical Summary
display(df.describe())
# Out:
#  Feuture Engineering start...
#            InvoiceNo       Quantity                    InvoiceDate  \
# count  397884.000000  397884.000000                         397884
# mean   560616.934451      12.988238  2011-07-10 23:41:23.511023360
# min    536365.000000       1.000000            2010-12-01 08:26:00
# 25%    549234.000000       2.000000            2011-04-07 11:12:00
# 50%    561893.000000       6.000000            2011-07-31 14:39:00
# 75%    572090.000000      12.000000            2011-10-20 14:33:00
# max    581587.000000   80995.000000            2011-12-09 12:50:00
# std     13106.117773     179.331775                            NaN
#
#            UnitPrice     CustomerID   TotalRevenue           Year  \
# count  397884.000000  397884.000000  397884.000000  397884.000000
# mean        3.116488   15294.423453      22.397000    2010.934260
# min         0.001000   12346.000000       0.001000    2010.000000
# 25%         1.250000   13969.000000       4.680000    2011.000000
# 50%         1.950000   15159.000000      11.800000    2011.000000
# 75%         3.750000   16795.000000      19.800000    2011.000000
# max      8142.750000   18287.000000  168469.600000    2011.000000
# std        22.097877    1713.141560     309.071041       0.247828
#
#                Month
# count  397884.000000
# mean        7.612475
# min         1.000000
# 25%         5.000000
# 50%         8.000000
# 75%        11.000000
# max        12.000000
# std         3.416520
