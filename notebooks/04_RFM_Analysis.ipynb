# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..')))
from src.rfm_analysis import perform_rfm_analysis
import pandas as pd

# 1. CSV data read
df = pd.read_csv('../data/processed/cleaned_online_retail.csv')

# 2. datatime convert to invoicedate
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# 3. RFM Analysis 
rfm_df = perform_rfm_analysis(df)

# 4. Saving (Save this as customer_summary.csv according to your new structure)
rfm_df.to_csv('../data/processed/customer_summary.csv', index=False)

display(rfm_df.head())
# Out:
# RFM Analysis starting..
# RFM Segmentation conplete !
#    CustomerID  Recency  Frequency  Monetary R_Score F_Score M_Score  \
# 0       12346      326          1  77183.60       1       1       5
# 1       12347        2          7   4310.00       5       5       5
# 2       12348       75          4   1797.24       2       4       4
# 3       12349       19          1   1757.55       4       1       4
# 4       12350      310          1    334.40       1       1       2
#
#               Customer_Segment
# 0  Average/Potential Loyalists
# 1       High-Value / Champions
# 2    At Risk / Can't Lose Them
# 3  Average/Potential Loyalists
# 4           Lost / Hibernating
